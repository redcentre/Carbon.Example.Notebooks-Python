# %% [markdown]
# ### Carbon Python Sample No.3 - SPSS to Heat Map Chart
#
# TODO: Add an introduction
#
# :star: The 21MB binary data file of SPSS data used by the example can be downloaded from: [Demo_21_24_with_caseid.sav](https://systemrcs.blob.core.windows.net/download/Demo_21_24_with_Caseid.sav)

# %%
import pandas as pd
import os
import numpy as np
import itertools
import plotly.express as px
import seaborn as sns
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import re
import pyreadstat
from pandas.api.types import CategoricalDtype

from natsort import natsorted, index_natsorted, order_by_index

import requests
from collections import Counter #(capital 'C')
NoAnsString='Unknown'


import PyCommon as pc

def naturalSort(dfdf:pd.DataFrame):
    dfdf = dfdf.reindex(index=natsorted(dfdf.index))
    return dfdf

# %% [markdown]
# ### Read the data in from an SPSS.sav file

# %%
df,meta= pyreadstat.read_sav(r'Demo_21_24_with_caseid.sav',apply_value_formats=True, 
                                formats_as_category=True, formats_as_ordered_category=False)
df[:2]
# Out:
#       DayNum   IND PRMSHP                   CCF                  CPF  \
# 0  04-Jan-21  None    Yes   At least once a day  A few times a month
# 1  04-Jan-21  None    Yes  Several times a week  A few times a month
#
#                 WUBY WUBYsup    TMBA  UOBA_1  UOBA_2  ...     GEN Married  \
# 0   Department Store          Brand7  Brand2  Brand4  ...  Female      No
# 1  Convenience Store          Brand7  Brand2  Brand4  ...    Male     Yes
#
#        Household HHSZ NCHLD          EDU          INC Income RawIncome Indent
# 0  Middle Family    3     4  HIGH SCHOOL  $30k to 50k  $4000    4000.0    1.0
# 1  Middle Family    3     2     BACHELOR    Over $75k  $9000    9000.0    2.0
#
# [2 rows x 145 columns]

# %%
meta.column_names
# Out:
# ['DayNum',
#  'IND',
#  'PRMSHP',
#  'CCF',
#  'CPF',
#  'WUBY',
#  'WUBYsup',
#  'TMBA',
#  'UOBA_1',
#  'UOBA_2',
#  'UOBA_3',
#  'UOBA_4',
#  'UOBA_5',
#  'UOBA_6',
#  'TMAA',
#  'UOAA_1',
#  'UOAA_2',
#  'UOAA_3',
#  'ABA_1',
#  'ABA_2',
#  'ABA_3',
#  'AAATV_1',
#  'AAATV_2',
#  'AAATV_3',
#  'AAAOM_1',
#  'AAAOM_2',
#  'AAAOM_3',
#  'BIM_1_1',
#  'BIM_1_2',
#  'BIM_1_3',
#  'BIM_1_4',
#  'BIM_1_5',
#  'BIM_1_6',
#  'BIM_1_7',
#  'BIM_1_8',
#  'BIM_1_9',
#  'BIM_1_10',
#  'BIM_2_1',
#  'BIM_2_2',
#  'BIM_2_3',
#  'BIM_2_4',
#  'BIM_2_5',
#  'BIM_2_6',
#  'BIM_2_7',
#  'BIM_2_8',
#  'BIM_2_9',
#  'BIM_2_10',
#  'BIM_3_1',
#  'BIM_3_2',
#  'BIM_3_3',
#  'BIM_3_4',
#  'BIM_3_5',
#  'BIM_3_6',
#  'BIM_3_7',
#  'BIM_3_8',
#  'BIM_3_9',
#  'BIM_3_10',
#  'BEQ_1_1',
#  'BEQ_1_2',
#  'BEQ_1_3',
#  'BEQ_1_4',
#  'BEQ_1_5',
#  'BEQ_1_6',
#  'BEQ_1_7',
#  'BEQ_2_1',
#  'BEQ_2_2',
#  'BEQ_2_3',
#  'BEQ_2_4',
#  'BEQ_2_5',
#  'BEQ_2_6',
#  'BEQ_2_7',
#  'BEQ_3_1',
#  'BEQ_3_2',
#  'BEQ_3_3',
#  'BEQ_3_4',
#  'BEQ_3_5',
#  'BEQ_3_6',
#  'BEQ_3_7',
#  'BratRats_1_1',
#  'BratRats_1_2',
#  'BratRats_2_1',
#  'BratRats_2_2',
#  'NPS_1',
#  'NPS_2',
#  'NPS_3',
#  'FavRat_1',
#  'FavRat_2',
#  'FavRat_3',
#  'EXITEMbrx_1',
#  'EXITEMbrx_2',
#  'EXITEMbrx_3',
#  'EXMESbrx_1',
#  'EXMESbrx_2',
#  'EXMESbrx_3',
#  'EXITEMbry_1',
#  'EXITEMbry_2',
#  'EXITEMbry_3',
#  'EXMESbry_1',
#  'EXMESbry_2',
#  'EXMESbry_3',
#  'EXITEMbrz',
#  'EXMESbrz_1',
#  'EXMESbrz_2',
#  'EXMESbrz_3',
#  'BPRF',
#  'BBL',
#  'BBE_1',
#  'BBE_2',
#  'BBE_3',
#  'BBE_4',
#  'BBE_5',
#  'BBE_6',
#  'PRCHINT_1',
#  'PRCHINT_2',
#  'PRCHINT_3',
#  'PRCHINT_4',
#  'PRCHINT_5',
#  'PRCHINT_6',
#  'BCON_1',
#  'BCON_2',
#  'BCON_3',
#  'BYL3M_1',
#  'BYL3M_2',
#  'BYL3M_3',
#  'BYREG_1',
#  'BYREG_2',
#  'BYREG_3',
#  'BYMST',
#  'PRICE',
#  'BYNUM',
#  'Q1aVx',
#  'Age',
#  'AgeX',
#  'Region',
#  'Occupation',
#  'GEN',
#  'Married',
#  'Household',
#  'HHSZ',
#  'NCHLD',
#  'EDU',
#  'INC',
#  'Income',
#  'RawIncome',
#  'Indent']

# %% [markdown]
# ### Change NaNs to the NoAnsString

# %%
def isNaN(x):
    return x!=x

def removeCatNaNs(nas:str):
    global df
    for col in df.columns:
        entries=[]
        if df[col].isna().values.any():
            for r in df[col]:
                if isNaN(r):
                    entries.append(nas)
                else:
                    entries.append(r)
        if len(entries) == len(df):
            df[col]=pd.Categorical(entries)
    return df
    
df=removeCatNaNs(NoAnsString)
df[:2]
# Out:
#       DayNum   IND PRMSHP                   CCF                  CPF  \
# 0  04-Jan-21  None    Yes   At least once a day  A few times a month
# 1  04-Jan-21  None    Yes  Several times a week  A few times a month
#
#                 WUBY WUBYsup    TMBA  UOBA_1  UOBA_2  ...     GEN Married  \
# 0   Department Store          Brand7  Brand2  Brand4  ...  Female      No
# 1  Convenience Store          Brand7  Brand2  Brand4  ...    Male     Yes
#
#        Household HHSZ NCHLD          EDU          INC Income RawIncome Indent
# 0  Middle Family    3     4  HIGH SCHOOL  $30k to 50k  $4000    4000.0    1.0
# 1  Middle Family    3     2     BACHELOR    Over $75k  $9000    9000.0    2.0
#
# [2 rows x 145 columns]

# %% [markdown]
# ### The API call is wrapped into the function carboncrosstab

# %%
table = pc.carboncrosstab(df.GEN,df['Age'],True)
table=naturalSort(table)
table
# Out:
#        Female   Male
# 15-25   19.46  19.14
# 26-35   19.64  18.68
# 36-50   20.28  19.92
# 51-65   19.80  20.88
# 65+     20.82  21.38

# %%
monthdict={1:'Jan',2:'Feb',3:'Mar',4:'Apr',5:'May',6:'Jun',7:'Jul',8:'Aug',9:'Sep',10:'Oct',11:'Nov',12:'Dec'}
# date=[]
monthyear=[]
for d in df['DayNum']:
    dateparts=d.split('-')
    monthyear.append(str(dateparts[1] + '-' + dateparts[2]))
df['monthyear']=monthyear

# %% [markdown]
# ### Multi-coded variables are very common in Market Research
#
#   In this example we are combinning 'Top of Mind' Awareness ('TMBA'), with 'Other Bransds aware of' (UOBA_1 to UOBA_6).
#
# All the variales have the same code frame, as defined in 'BrandDict'

# %%
mvars=['UOBA','UOAA','ABA','AAATV','AAAOM']


for mvar in mvars:
    targetcols=[]
    var=[]
    for coll in df.columns:
        if coll.startswith(mvar + '_'):
            targetcols.append(coll)
    tc=df[targetcols].T
    for resp in tc.columns:
        respentry=tc[resp].to_list()
        while NoAnsString in respentry:
            respentry.remove(NoAnsString)
        var.append(respentry)
    df[mvar]=var

# %% [markdown]
# ### Combine TMBA and the new UOBA to create UBA
#
# TMBA = Top of mind awareness, the first brand mentioned
#
# UOBA = Other Brands mentioned
#
# UBA = UnAided Brand Awareness

# %%
var=[]
tc=df[['TMBA','UOBA']].T
for resp in tc.columns:
    respentry=tc[resp][1]
    respentry.append(tc[resp][0])
    ree=np.array(respentry)
    r=np.unique(ree).tolist()
    var.append(r[1:])

df['UBA']=var

df['UBA']
# Out:
# 0               [Brand2, Brand4, Brand7]
# 1               [Brand2, Brand4, Brand7]
# 2       [Brand2, Brand6, Brand7, Brand8]
# 3                      [Brand10, Brand2]
# 4       [Brand1, Brand2, Brand4, Brand6]
#                       ...
# 9995    [Brand1, Brand3, Brand5, Brand6]
# 9996    [Brand2, Brand4, Brand5, Brand7]
# 9997    [Brand1, Brand2, Brand3, Brand4]
# 9998            [Brand1, Brand2, Brand5]
# 9999    [Brand1, Brand2, Brand3, Brand8]
# Name: UBA, Length: 10000, dtype: object

# %%
tab1=pc.carboncrosstab(df['GEN'], df['UBA'], True)
tab1=naturalSort(tab1)
tab1
# Out:
#          Female   Male
# Brand1    67.04  66.10
# Brand2    46.44  47.10
# Brand3    58.40  60.02
# Brand4    50.43  51.82
# Brand5    37.07  37.93
# Brand6    28.00  28.02
# Brand7    19.50  18.96
# Brand8    11.72  11.45
# Brand9     7.76   6.72
# Brand10   12.56  13.48

# %% [markdown]
# ### An NPS calculation

# %%
subBrandDict = {1:'Brand1', 2 : 'Brand2', 3:'Brand3'}
for b in subBrandDict:
    nps=[]
    for i,r in df.iterrows():
        entry=[]
        score=r['NPS_' + str(b)]
        entry.append(score)
        npstype='Passive'
        if int(score) <=6:
            npstype='Detractor'
        if int(score) >=9:
            npstype='Promoter'
        entry.append(npstype)
        nps.append(entry)
    df['nps_' + subBrandDict.get(b)]=nps
    
df['nps_Brand1']
# Out:
# 0       [1, Detractor]
# 1       [2, Detractor]
# 2       [1, Detractor]
# 3       [2, Detractor]
# 4         [8, Passive]
#              ...
# 9995    [2, Detractor]
# 9996    [10, Promoter]
# 9997    [2, Detractor]
# 9998    [3, Detractor]
# 9999    [4, Detractor]
# Name: nps_Brand1, Length: 10000, dtype: object

# %%
table=naturalSort(pc.carboncrosstab(df['GEN'],df['nps_Brand1'], True))
table
# Out:
#            Female   Male
# 1            2.93   2.83
# 2           11.51  11.41
# 3            4.21   4.29
# 4            5.40   4.97
# 5            6.40   6.56
# 6           10.05   9.43
# 7            7.66   8.39
# 8           19.52  19.72
# 9           23.37  23.43
# 10           8.95   8.97
# Detractor   40.50  39.50
# Passive     27.18  28.10
# Promoter    32.32  32.40

# %%
def makeBanner():
    bannercol=[]
    for i,r in df.iterrows():
        respentry=[]
        respentry.append('Total')

        if r['GEN']=='Males':
            respentry.append('Male')
        else:
            respentry.append('Female')

        respentry.append(r['Age'])
        respentry.append(r['Region'])
        # respentry.append(r['BBL'])

        bannercol.append(respentry)
    return bannercol

df['banner']=makeBanner()
df['banner']
# Out:
# 0       [Total, Female, 36-50, SE]
# 1       [Total, Female, 51-65, SE]
# 2       [Total, Female, 26-35, NW]
# 3       [Total, Female, 15-25, NW]
# 4       [Total, Female, 26-35, SE]
#                    ...
# 9995    [Total, Female, 15-25, NW]
# 9996      [Total, Female, 65+, SW]
# 9997    [Total, Female, 51-65, NW]
# 9998      [Total, Female, 65+, NE]
# 9999    [Total, Female, 15-25, NW]
# Name: banner, Length: 10000, dtype: object

# %%
ct= pc.carboncrosstab(df['monthyear'],df['UBA'], True)
ct=naturalSort(ct).round(1)

cm = sns.light_palette("blue", as_cmap=True)
ct.style.background_gradient(cmap=cm,subset=(ct.index[:], ct.select_dtypes(float).columns)).applymap(lambda v: 'opacity: 50%;' if (v < 10) else None ).format(precision=1)
# Out:
# <style type="text/css">
# #T_40d27_row0_col0, #T_40d27_row0_col1, #T_40d27_row0_col2, #T_40d27_row0_col3, #T_40d27_row0_col5, #T_40d27_row0_col6, #T_40d27_row0_col7, #T_40d27_row0_col9, #T_40d27_row0_col10, #T_40d27_row0_col11, #T_40d27_row0_col12, #T_40d27_row0_col13, #T_40d27_row0_col14, #T_40d27_row0_col15, #T_40d27_row0_col17, #T_40d27_row0_col18, #T_40d27_row0_col19, #T_40d27_row0_col21, #T_40d27_row0_col22, #T_40d27_row0_col23, #T_40d27_row0_col24, #T_40d27_row0_col25, #T_40d27_row0_col26, #T_40d27_row0_col27, #T_40d27_row0_col28, #T_40d27_row0_col29, #T_40d27_row0_col30, #T_40d27_row0_col31, #T_40d27_row0_col32, #T_40d27_row0_col33, #T_40d27_row0_col34, #T_40d27_row0_col35, #T_40d27_row0_col36, #T_40d27_row0_col37, #T_40d27_row0_col38, #T_40d27_row0_col39, #T_40d27_row0_col40, #T_40d27_row0_col41, #T_40d27_row0_col42, #T_40d27_row0_col43, #T_40d27_row0_col44, #T_40d27_row0_col45, #T_40d27_row2_col4, #T_40d27_row2_col8, #T_40d27_row2_col16, #T_40d27_row2_col20, #T_40d27_row2_col42, #T_40d27_row2_col45, #T_40d27_row2_col46 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_40d27_row0_col4, #T_40d27_row0_col20 {
#   background-color: #0a0afe;
#   color: #f1f1f1;
# }
# #T_40d27_row0_col8 {
#   background-color: #0404ff;
#   color: #f1f1f1;
# }
# #T_40d27_row0_col16, #T_40d27_row3_col11 {
#   background-color: #1414fe;
#   color: #f1f1f1;
# }
# #T_40d27_row0_col46, #T_40d27_row2_col32 {
#   background-color: #0909ff;
#   color: #f1f1f1;
# }
# #T_40d27_row1_col0, #T_40d27_row4_col15, #T_40d27_row4_col18 {
#   background-color: #6161fa;
#   color: #f1f1f1;
# }
# #T_40d27_row1_col1, #T_40d27_row1_col8 {
#   background-color: #4e4efb;
#   color: #f1f1f1;
# }
# #T_40d27_row1_col2, #T_40d27_row1_col30 {
#   background-color: #5b5bfa;
#   color: #f1f1f1;
# }
# #T_40d27_row1_col3, #T_40d27_row2_col37 {
#   background-color: #2d2dfd;
#   color: #f1f1f1;
# }
# #T_40d27_row1_col4, #T_40d27_row2_col14 {
#   background-color: #4242fc;
#   color: #f1f1f1;
# }
# #T_40d27_row1_col5, #T_40d27_row1_col15, #T_40d27_row1_col24, #T_40d27_row3_col38 {
#   background-color: #4a4afb;
#   color: #f1f1f1;
# }
# #T_40d27_row1_col6, #T_40d27_row3_col7, #T_40d27_row3_col9, #T_40d27_row3_col33 {
#   background-color: #2929fd;
#   color: #f1f1f1;
# }
# #T_40d27_row1_col7 {
#   background-color: #5656fb;
#   color: #f1f1f1;
# }
# #T_40d27_row1_col9 {
#   background-color: #4f4ffb;
#   color: #f1f1f1;
# }
# #T_40d27_row1_col10, #T_40d27_row1_col33, #T_40d27_row3_col16 {
#   background-color: #4646fb;
#   color: #f1f1f1;
# }
# #T_40d27_row1_col11, #T_40d27_row2_col28, #T_40d27_row2_col41, #T_40d27_row3_col5 {
#   background-color: #3535fc;
#   color: #f1f1f1;
# }
# #T_40d27_row1_col12 {
#   background-color: #5a5afa;
#   color: #f1f1f1;
# }
# #T_40d27_row1_col13, #T_40d27_row3_col1 {
#   background-color: #4b4bfb;
#   color: #f1f1f1;
# }
# #T_40d27_row1_col14, #T_40d27_row1_col35 {
#   background-color: #4848fb;
#   color: #f1f1f1;
# }
# #T_40d27_row1_col16 {
#   background-color: #6060fa;
#   color: #f1f1f1;
# }
# #T_40d27_row1_col17, #T_40d27_row1_col26 {
#   background-color: #5353fb;
#   color: #f1f1f1;
# }
# #T_40d27_row1_col18 {
#   background-color: #4343fc;
#   color: #f1f1f1;
# }
# #T_40d27_row1_col19, #T_40d27_row1_col23, #T_40d27_row3_col0 {
#   background-color: #4c4cfb;
#   color: #f1f1f1;
# }
# #T_40d27_row1_col20, #T_40d27_row1_col21 {
#   background-color: #4949fb;
#   color: #f1f1f1;
# }
# #T_40d27_row1_col22, #T_40d27_row4_col4 {
#   background-color: #7373f9;
#   color: #f1f1f1;
# }
# #T_40d27_row1_col25, #T_40d27_row3_col25, #T_40d27_row3_col35 {
#   background-color: #6363fa;
#   color: #f1f1f1;
# }
# #T_40d27_row1_col27, #T_40d27_row1_col34, #T_40d27_row1_col39 {
#   background-color: #6262fa;
#   color: #f1f1f1;
# }
# #T_40d27_row1_col28, #T_40d27_row1_col46, #T_40d27_row3_col34, #T_40d27_row4_col24 {
#   background-color: #5e5efa;
#   color: #f1f1f1;
# }
# #T_40d27_row1_col29, #T_40d27_row3_col17, #T_40d27_row3_col23 {
#   background-color: #5151fb;
#   color: #f1f1f1;
# }
# #T_40d27_row1_col31 {
#   background-color: #6a6afa;
#   color: #f1f1f1;
# }
# #T_40d27_row1_col32, #T_40d27_row1_col42, #T_40d27_row3_col41 {
#   background-color: #5454fb;
#   color: #f1f1f1;
# }
# #T_40d27_row1_col36, #T_40d27_row3_col28 {
#   background-color: #5c5cfa;
#   color: #f1f1f1;
# }
# #T_40d27_row1_col37 {
#   background-color: #5757fb;
#   color: #f1f1f1;
# }
# #T_40d27_row1_col38, #T_40d27_row4_col10 {
#   background-color: #5858fb;
#   color: #f1f1f1;
# }
# #T_40d27_row1_col40, #T_40d27_row3_col36, #T_40d27_row3_col40 {
#   background-color: #5252fb;
#   color: #f1f1f1;
# }
# #T_40d27_row1_col41 {
#   background-color: #7070f9;
#   color: #f1f1f1;
# }
# #T_40d27_row1_col43, #T_40d27_row4_col6 {
#   background-color: #4040fc;
#   color: #f1f1f1;
# }
# #T_40d27_row1_col44, #T_40d27_row3_col2, #T_40d27_row3_col3, #T_40d27_row3_col10 {
#   background-color: #2b2bfd;
#   color: #f1f1f1;
# }
# #T_40d27_row1_col45, #T_40d27_row2_col29 {
#   background-color: #2727fd;
#   color: #f1f1f1;
# }
# #T_40d27_row2_col0 {
#   background-color: #2c2cfd;
#   color: #f1f1f1;
# }
# #T_40d27_row2_col1, #T_40d27_row2_col6, #T_40d27_row2_col7, #T_40d27_row2_col39, #T_40d27_row3_col8 {
#   background-color: #1919fe;
#   color: #f1f1f1;
# }
# #T_40d27_row2_col2, #T_40d27_row2_col9, #T_40d27_row2_col40, #T_40d27_row3_col6, #T_40d27_row3_col14, #T_40d27_row3_col42, #T_40d27_row3_col46 {
#   background-color: #2828fd;
#   color: #f1f1f1;
# }
# #T_40d27_row2_col3 {
#   background-color: #0606ff;
#   color: #f1f1f1;
# }
# #T_40d27_row2_col5 {
#   background-color: #3737fc;
#   color: #f1f1f1;
# }
# #T_40d27_row2_col10, #T_40d27_row2_col13, #T_40d27_row2_col33 {
#   background-color: #1f1ffd;
#   color: #f1f1f1;
# }
# #T_40d27_row2_col11, #T_40d27_row2_col43 {
#   background-color: #0202ff;
#   color: #f1f1f1;
# }
# #T_40d27_row2_col12 {
#   background-color: #1313fe;
#   color: #f1f1f1;
# }
# #T_40d27_row2_col15, #T_40d27_row2_col24 {
#   background-color: #0d0dfe;
#   color: #f1f1f1;
# }
# #T_40d27_row2_col17, #T_40d27_row2_col30 {
#   background-color: #3333fc;
#   color: #f1f1f1;
# }
# #T_40d27_row2_col18 {
#   background-color: #1717fe;
#   color: #f1f1f1;
# }
# #T_40d27_row2_col19 {
#   background-color: #1a1afe;
#   color: #f1f1f1;
# }
# #T_40d27_row2_col21, #T_40d27_row3_col45 {
#   background-color: #2e2efd;
#   color: #f1f1f1;
# }
# #T_40d27_row2_col22 {
#   background-color: #3e3efc;
#   color: #f1f1f1;
# }
# #T_40d27_row2_col23, #T_40d27_row2_col31, #T_40d27_row3_col43 {
#   background-color: #3232fc;
#   color: #f1f1f1;
# }
# #T_40d27_row2_col25 {
#   background-color: #3838fc;
#   color: #f1f1f1;
# }
# #T_40d27_row2_col26 {
#   background-color: #1212fe;
#   color: #f1f1f1;
# }
# #T_40d27_row2_col27 {
#   background-color: #1c1cfe;
#   color: #f1f1f1;
# }
# #T_40d27_row2_col34, #T_40d27_row3_col15 {
#   background-color: #2626fd;
#   color: #f1f1f1;
# }
# #T_40d27_row2_col35 {
#   background-color: #0505ff;
#   color: #f1f1f1;
# }
# #T_40d27_row2_col36 {
#   background-color: #2f2ffd;
#   color: #f1f1f1;
# }
# #T_40d27_row2_col38 {
#   background-color: #4444fc;
#   color: #f1f1f1;
# }
# #T_40d27_row2_col44, #T_40d27_row3_col4, #T_40d27_row3_col44 {
#   background-color: #1d1dfe;
#   color: #f1f1f1;
# }
# #T_40d27_row3_col12, #T_40d27_row3_col26 {
#   background-color: #4141fc;
#   color: #f1f1f1;
# }
# #T_40d27_row3_col13, #T_40d27_row3_col30 {
#   background-color: #3d3dfc;
#   color: #f1f1f1;
# }
# #T_40d27_row3_col18, #T_40d27_row3_col32 {
#   background-color: #3f3ffc;
#   color: #f1f1f1;
# }
# #T_40d27_row3_col19 {
#   background-color: #3636fc;
#   color: #f1f1f1;
# }
# #T_40d27_row3_col20, #T_40d27_row3_col27 {
#   background-color: #4747fb;
#   color: #f1f1f1;
# }
# #T_40d27_row3_col21, #T_40d27_row3_col22 {
#   background-color: #3a3afc;
#   color: #f1f1f1;
# }
# #T_40d27_row3_col24 {
#   background-color: #3c3cfc;
#   color: #f1f1f1;
# }
# #T_40d27_row3_col29 {
#   background-color: #5f5ffa;
#   color: #f1f1f1;
# }
# #T_40d27_row3_col31 {
#   background-color: #6b6bfa;
#   color: #f1f1f1;
# }
# #T_40d27_row3_col37 {
#   background-color: #4545fb;
#   color: #f1f1f1;
# }
# #T_40d27_row3_col39 {
#   background-color: #6e6ef9;
#   color: #f1f1f1;
# }
# #T_40d27_row4_col0, #T_40d27_row4_col31, #T_40d27_row5_col10 {
#   background-color: #8585f8;
#   color: #f1f1f1;
# }
# #T_40d27_row4_col1 {
#   background-color: #7575f9;
#   color: #f1f1f1;
# }
# #T_40d27_row4_col2, #T_40d27_row4_col33, #T_40d27_row4_col37, #T_40d27_row4_col40 {
#   background-color: #7c7cf9;

# %%
import plotly.express as px

fig=px.line(ct.T)  # Need to transpose the crosstab
fig.show()
